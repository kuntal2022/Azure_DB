# %% [markdown]
# <h3>To access data from ADLS gen2 storage through Service Prinicipal</h3>
# <h6> 1. Registraion with Microsoft Entra Id or AD application</h6>
# <h6>2. Get the client id, directory id and the secrete </h6>
# <h6>3. Assign Storage Blob Data contributor role</h6>
# <h6>4. Configure with spark </h6>

# %%
app_id= "e5b034b4-bdff-45fa-8e8e-7d78dccfc61b"
tn_id= "d5e518ae-512f-4b0e-9488-07ba34264acd"
pass_word="owu8Q~OHXD2Go1rDTefANPdmTLTn_URKHyxqNaPK"

# %%
app_id = "e5b034b4-bdff-45fa-8e8e-7d78dccfc61b"
tenant_id = "d5e518ae-512f-4b0e-9488-07ba34264acd"
password = "owu8Q~OHXD2Go1rDTefANPdmTLTn_URKHyxqNaPK"

spark.conf.set("fs.azure.account.auth.type.db1stroarge1practice.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.db1stroarge1practice.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.db1stroarge1practice.dfs.core.windows.net", app_id)
spark.conf.set("fs.azure.account.oauth2.client.secret.db1stroarge1practice.dfs.core.windows.net", pass_word)
spark.conf.set("fs.azure.account.oauth2.client.endpoint.db1stroarge1practice.dfs.core.windows.net", f"https://login.microsoftonline.com/{tn_id}/oauth2/token")

# %% [markdown]
# Spark config for Service Principal or Microsoft Entra ID:
# https://learn.microsoft.com/en-us/azure/databricks/connect/storage/azure-storage#--access-azure-data-lake-storage-gen2-or-blob-storage-using-oauth-20-with-an-azure-service-principal

# %%
display(dbutils.fs.ls("abfss://container1@db1stroarge1practice.dfs.core.windows.net"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>abfss://container1@db1stroarge1practice.dfs.core.windows.net/Sample - Superstore.xlsx</td><td>Sample - Superstore.xlsx</td><td>1395580</td><td>1714220298000</td></tr><tr><td>abfss://container1@db1stroarge1practice.dfs.core.windows.net/Walmart.csv</td><td>Walmart.csv</td><td>377988</td><td>1714224355000</td></tr></tbody></table></div>

# %%
df=spark.read.csv("abfss://container1@db1stroarge1practice.dfs.core.windows.net/Walmart.csv", header=True, inferSchema=True)

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
